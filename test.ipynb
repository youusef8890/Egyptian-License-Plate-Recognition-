# %% [markdown]
# ## test on pic

# %%
import cv2
from ultralytics import YOLO
import torch
import numpy as np
import arabic_reshaper
from bidi.algorithm import get_display
from PIL import Image, ImageDraw, ImageFont
import pyautogui  # 📌 To get screen size dynamically

# Mapping class IDs to Arabic characters
id2char = {
    0: 'أ', 1: 'ب', 2: 'ج', 3: 'د', 4: 'ر', 5: 'س', 6: 'ص', 7: 'ط', 8: 'ع', 9: 'ف',
    10: 'ق', 11: 'ل', 12: 'م', 13: 'ن', 14: 'ھ', 15: 'و', 16: 'ى',
    17: '٠', 18: '١', 19: '٢', 20: '٣', 21: '٤', 22: '٥', 23: '٦', 24: '٧', 25: '٨', 26: '٩'
}

# Load YOLO models
plate_model = YOLO("best.pt")       # Replace with your trained plate detector
char_model = YOLO("chars.pt")       # Replace with your trained character detector

# Load and prepare the image
img = cv2.imread("o.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Step 1: Detect license plate
plate_results = plate_model(img_rgb)[0]
if len(plate_results.boxes) == 0:
    print("❌ No plate found")
    exit()

# Use the first detected plate
plate_box = plate_results.boxes[0].xyxy[0].cpu().numpy().astype(int)
x1, y1, x2, y2 = plate_box
plate_crop = img[y1:y2, x1:x2]

# Step 2: Detect characters on the cropped plate
char_results = char_model(plate_crop)[0]
char_boxes = char_results.boxes

if len(char_boxes) == 0:
    print("❌ No characters found on plate")
    exit()

digit_indices = set(range(17, 27))
letters = []
digits = []

# Draw bounding boxes on cropped plate (no text)
for box, cls in zip(char_boxes.xyxy, char_boxes.cls):
    x1_c, y1_c, x2_c, y2_c = map(int, box)
    x_center = (x1_c + x2_c) / 2
    char = id2char[int(cls)]

    cv2.rectangle(plate_crop, (x1_c, y1_c), (x2_c, y2_c), (0, 255, 0), 2)

    if int(cls) in digit_indices:
        digits.append((x_center, char))
    else:
        letters.append((x_center, char))

# Sort characters
letters.sort(key=lambda x: x[0])  # RTL
digits.sort(key=lambda x: x[0])   # LTR

# Compose final plate text
arabic_letters = ' '.join([char for _, char in reversed(letters)])  # RTL
arabic_digits = ''.join([char for _, char in digits])
final_plate = arabic_letters + ' ' + arabic_digits

print("✅ Detected Plate Text:", final_plate)

# ===== Arabic Reshaping and Text Rendering =====
reshaped_text = arabic_reshaper.reshape(final_plate)
bidi_text = get_display(reshaped_text)

# Convert image to PIL
img_pil = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
draw = ImageDraw.Draw(img_pil)

# Load Arabic-supporting font
try:
    font = ImageFont.truetype("arial.ttf", 40)  # Windows
except:
    font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 40)  # Linux

# Draw Arabic text above the plate
draw.text((x1, y1 - 50), bidi_text, font=font, fill=(255, 0, 0))
draw.rectangle([x1, y1, x2, y2], outline=(0, 0, 255), width=4)

# Convert back to OpenCV format
img_annotated = cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)

# ===== 📌 Resize for Display Based on Screen Size =====
screen_width, screen_height = pyautogui.size()
max_display_width = int(screen_width * 0.9)
max_display_height = int(screen_height * 0.9)

h, w = img_annotated.shape[:2]
scale_w = max_display_width / w
scale_h = max_display_height / h
scale = min(scale_w, scale_h, 1.0)  # Do not upscale

new_w = int(w * scale)
new_h = int(h * scale)
resized_img = cv2.resize(img_annotated, (new_w, new_h))

# ===== Show and Save Result =====
cv2.imshow("Detected Plate", resized_img)
cv2.imwrite("annotated_plate.jpg", img_annotated)  # Save full resolution
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 800x704 1 License Plate, 31.3ms
# Speed: 6.6ms preprocess, 31.3ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 704)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 16.8ms
# Speed: 1.3ms preprocess, 16.8ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
# ✅ Detected Plate Text: ر أ م ١١١١

# %% [markdown]
# ## test video

# %%
import cv2
from ultralytics import YOLO
import torch
import numpy as np
import arabic_reshaper
from bidi.algorithm import get_display
from PIL import Image, ImageDraw, ImageFont
import pyautogui  # For screen size

# Arabic character map
id2char = {
    0: 'أ', 1: 'ب', 2: 'ج', 3: 'د', 4: 'ر', 5: 'س', 6: 'ص', 7: 'ط', 8: 'ع', 9: 'ف',
    10: 'ق', 11: 'ل', 12: 'م', 13: 'ن', 14: 'ھ', 15: 'و', 16: 'ى',
    17: '٠', 18: '١', 19: '٢', 20: '٣', 21: '٤', 22: '٥', 23: '٦', 24: '٧', 25: '٨', 26: '٩'
}

# Load models
plate_model = YOLO("best.pt")
char_model = YOLO("chars.pt")

# Font loading (adjust path if needed)
try:
    font = ImageFont.truetype("arial.ttf", 40)  # Windows
except:
    font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 40)  # Linux

# Screen size
screen_width, screen_height = pyautogui.size()

# === VIDEO SETUP ===
video_path = "testvideo.mp4"  # 0 = webcam, or replace with "video.mp4"
cap = cv2.VideoCapture(video_path)

# Optional: save output
save_output = False
if save_output:
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter("output_video.mp4", fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    plate_results = plate_model(img_rgb)[0]

    img_pil = Image.fromarray(img_rgb)
    draw = ImageDraw.Draw(img_pil)

    for plate_box in plate_results.boxes:
        x1, y1, x2, y2 = plate_box.xyxy[0].cpu().numpy().astype(int)
        plate_crop = frame[y1:y2, x1:x2]
        char_results = char_model(plate_crop)[0]
        char_boxes = char_results.boxes

        if len(char_boxes) == 0:
            continue

        letters, digits = [], []
        for box, cls in zip(char_boxes.xyxy, char_boxes.cls):
            x1_c, y1_c, x2_c, y2_c = map(int, box)
            x_center = (x1_c + x2_c) / 2
            char = id2char[int(cls)]

            if int(cls) in range(17, 27):  # Digits
                digits.append((x_center, char))
            else:  # Letters
                letters.append((x_center, char))

        letters.sort(key=lambda x: x[0])
        digits.sort(key=lambda x: x[0])
        arabic_letters = ' '.join([char for _, char in reversed(letters)])
        arabic_digits = ''.join([char for _, char in digits])
        final_plate = arabic_letters + ' ' + arabic_digits

        reshaped_text = arabic_reshaper.reshape(final_plate)
        bidi_text = get_display(reshaped_text)

        draw.text((x1, y1 - 50), bidi_text, font=font, fill=(255, 0, 0))
        draw.rectangle([x1, y1, x2, y2], outline=(0, 255, 0), width=3)

    # Convert back to OpenCV image
    annotated_frame = cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)

    # Auto resize to fit screen if necessary
    frame_h, frame_w = annotated_frame.shape[:2]
    if frame_w > screen_width or frame_h > screen_height:
        scale = min(screen_width / frame_w, screen_height / frame_h)
        resized_frame = cv2.resize(annotated_frame, (int(frame_w * scale), int(frame_h * scale)))
    else:
        resized_frame = annotated_frame.copy()

    # Show result
    cv2.imshow("Arabic Plate Detection", resized_frame)

    if save_output:
        out.write(annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
if save_output:
    out.release()
cv2.destroyAllWindows()
# Out:
# 0: 800x480 (no detections), 78.6ms
# Speed: 14.3ms preprocess, 78.6ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 27.6ms
# Speed: 6.8ms preprocess, 27.6ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 31.9ms
# Speed: 8.5ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 33.5ms
# Speed: 11.0ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 34.2ms
# Speed: 11.8ms preprocess, 34.2ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 23.5ms
# Speed: 11.4ms preprocess, 23.5ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 35.5ms
# Speed: 8.1ms preprocess, 35.5ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 39.1ms
# Speed: 10.8ms preprocess, 39.1ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 50.6ms
# Speed: 12.3ms preprocess, 50.6ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 39.4ms
# Speed: 11.2ms preprocess, 39.4ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 59.2ms
# Speed: 11.9ms preprocess, 59.2ms inference, 3.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 21.5ms
# Speed: 6.9ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 29.6ms
# Speed: 6.4ms preprocess, 29.6ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 29.7ms
# Speed: 9.2ms preprocess, 29.7ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 29.3ms
# Speed: 5.8ms preprocess, 29.3ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 27.3ms
# Speed: 6.5ms preprocess, 27.3ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 20.5ms
# Speed: 7.3ms preprocess, 20.5ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 18.9ms
# Speed: 5.3ms preprocess, 18.9ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 16.3ms
# Speed: 5.6ms preprocess, 16.3ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 20.4ms
# Speed: 5.5ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 13.7ms
# Speed: 7.4ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.7ms
# Speed: 7.0ms preprocess, 15.7ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.9ms
# Speed: 7.3ms preprocess, 15.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 16.5ms
# Speed: 6.2ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.2ms
# Speed: 4.8ms preprocess, 15.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.6ms
# Speed: 6.6ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.3ms
# Speed: 4.2ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.1ms
# Speed: 5.4ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 14.5ms
# Speed: 5.6ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.1ms
# Speed: 4.2ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 14.5ms
# Speed: 4.8ms preprocess, 14.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 10.0ms
# Speed: 4.6ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.1ms
# Speed: 4.9ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 16.1ms
# Speed: 4.3ms preprocess, 16.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.1ms
# Speed: 5.8ms preprocess, 12.1ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.1ms
# Speed: 6.3ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 13.3ms
# Speed: 4.7ms preprocess, 13.3ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 10.2ms
# Speed: 5.2ms preprocess, 10.2ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 10.6ms
# Speed: 4.1ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.7ms
# Speed: 5.0ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 14.6ms
# Speed: 6.5ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.3ms
# Speed: 5.5ms preprocess, 12.3ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 13.5ms
# Speed: 8.3ms preprocess, 13.5ms inference, 0.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.4ms
# Speed: 4.5ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 13.7ms
# Speed: 7.5ms preprocess, 13.7ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.9ms
# Speed: 5.4ms preprocess, 15.9ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 14.1ms
# Speed: 5.4ms preprocess, 14.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.1ms
# Speed: 5.1ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 10.9ms
# Speed: 5.3ms preprocess, 10.9ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 11.6ms
# Speed: 5.1ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 19.2ms
# Speed: 6.1ms preprocess, 19.2ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 11.3ms
# Speed: 4.5ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.2ms
# Speed: 4.6ms preprocess, 12.2ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 13.9ms
# Speed: 6.5ms preprocess, 13.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.2ms
# Speed: 4.2ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.4ms
# Speed: 4.5ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 12.9ms
# Speed: 6.3ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.4ms
# Speed: 6.0ms preprocess, 15.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 16.9ms
# Speed: 6.4ms preprocess, 16.9ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 23.0ms
# Speed: 6.3ms preprocess, 23.0ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 16.3ms
# Speed: 6.0ms preprocess, 16.3ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 18.8ms
# Speed: 8.0ms preprocess, 18.8ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 18.2ms
# Speed: 7.4ms preprocess, 18.2ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 15.6ms
# Speed: 6.3ms preprocess, 15.6ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 16.0ms
# Speed: 6.4ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 14.9ms
# Speed: 7.5ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 16.0ms
# Speed: 6.0ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 (no detections), 14.9ms
# Speed: 6.5ms preprocess, 14.9ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License Plate, 13.2ms
# Speed: 5.0ms preprocess, 13.2ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 640x576 1 , 16.1ms
# Speed: 5.3ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 800x480 1 License Plate, 15.3ms
# Speed: 5.9ms preprocess, 15.3ms inference, 3.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 640x640 (no detections), 20.4ms
# Speed: 4.6ms preprocess, 20.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 800x480 1 License Plate, 12.0ms
# Speed: 6.4ms preprocess, 12.0ms inference, 3.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 608x640 1 , 14.1ms
# Speed: 5.7ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 800x480 1 License Plate, 25.8ms
# Speed: 9.8ms preprocess, 25.8ms inference, 4.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 544x640 1 , 18.4ms
# Speed: 5.6ms preprocess, 18.4ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 800x480 1 License Plate, 16.0ms
# Speed: 6.6ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 512x640 1 , 14.1ms
# Speed: 3.6ms preprocess, 14.1ms inference, 3.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 800x480 1 License Plate, 23.7ms
# Speed: 5.6ms preprocess, 23.7ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 448x640 1 , 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 800x480 1 License Plate, 16.0ms
# Speed: 7.0ms preprocess, 16.0ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 416x640 1 , 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 800x480 1 License Plate, 16.1ms
# Speed: 4.6ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 384x640 1 , 1 , 14.8ms
# Speed: 1.8ms preprocess, 14.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x480 (no detections), 13.0ms
# Speed: 5.9ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 800x480 1 License Plate, 15.4ms
# Speed: 5.1ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 11.3ms
# Speed: 1.7ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 13.0ms
# Speed: 4.9ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 1 , 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 13.1ms
# Speed: 5.0ms preprocess, 13.1ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 11.2ms
# Speed: 1.5ms preprocess, 11.2ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 13.7ms
# Speed: 5.1ms preprocess, 13.7ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 2 s, 1 , 1 , 1 , 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 12.8ms
# Speed: 4.4ms preprocess, 12.8ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 256x640 1 , 1 , 1 , 1 , 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 800x480 1 License Plate, 13.5ms
# Speed: 4.2ms preprocess, 13.5ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 256x640 1 , 1 , 1 , 1 , 14.7ms
# Speed: 1.6ms preprocess, 14.7ms inference, 2.6ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 800x480 1 License Plate, 13.2ms
# Speed: 5.7ms preprocess, 13.2ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 256x640 1 , 1 , 1 , 1 , 10.3ms
# Speed: 1.3ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 800x480 1 License Plate, 13.1ms
# Speed: 4.3ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 256x640 1 , 1 , 1 , 1 , 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 800x480 1 License Plate, 14.4ms
# Speed: 5.0ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 13.1ms
# Speed: 2.4ms preprocess, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 13.3ms
# Speed: 6.0ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 13.4ms
# Speed: 4.3ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 2 s, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.3ms
# Speed: 8.0ms preprocess, 18.3ms inference, 3.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 17.7ms
# Speed: 2.1ms preprocess, 17.7ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 20.1ms
# Speed: 6.2ms preprocess, 20.1ms inference, 5.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 29.3ms
# Speed: 2.9ms preprocess, 29.3ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 15.4ms
# Speed: 6.5ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 18.8ms
# Speed: 1.7ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.5ms
# Speed: 7.1ms preprocess, 18.5ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 18.9ms
# Speed: 2.3ms preprocess, 18.9ms inference, 2.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 17.7ms
# Speed: 6.5ms preprocess, 17.7ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 20.3ms
# Speed: 1.8ms preprocess, 20.3ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 14.6ms
# Speed: 5.1ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 15.1ms
# Speed: 5.7ms preprocess, 15.1ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 14.6ms
# Speed: 1.5ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 14.5ms
# Speed: 5.9ms preprocess, 14.5ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 14.7ms
# Speed: 5.3ms preprocess, 14.7ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 16.4ms
# Speed: 6.4ms preprocess, 16.4ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 14.9ms
# Speed: 6.7ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 16.3ms
# Speed: 1.5ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 15.1ms
# Speed: 6.3ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 16.8ms
# Speed: 1.5ms preprocess, 16.8ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 22.3ms
# Speed: 7.1ms preprocess, 22.3ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 20.1ms
# Speed: 2.9ms preprocess, 20.1ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 35.2ms
# Speed: 11.3ms preprocess, 35.2ms inference, 5.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 15.5ms
# Speed: 5.1ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 19.6ms
# Speed: 2.4ms preprocess, 19.6ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 15.9ms
# Speed: 5.3ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 2.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 16.8ms
# Speed: 8.2ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 13.5ms
# Speed: 2.8ms preprocess, 13.5ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 16.1ms
# Speed: 6.3ms preprocess, 16.1ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 16.2ms
# Speed: 5.3ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 17.7ms
# Speed: 2.1ms preprocess, 17.7ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 21.7ms
# Speed: 8.0ms preprocess, 21.7ms inference, 4.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 22.6ms
# Speed: 2.2ms preprocess, 22.6ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 16.6ms
# Speed: 7.0ms preprocess, 16.6ms inference, 4.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 25.9ms
# Speed: 3.7ms preprocess, 25.9ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 29.3ms
# Speed: 9.4ms preprocess, 29.3ms inference, 4.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 27.6ms
# Speed: 3.5ms preprocess, 27.6ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 17.1ms
# Speed: 7.9ms preprocess, 17.1ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 20.7ms
# Speed: 6.7ms preprocess, 20.7ms inference, 3.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 12.4ms
# Speed: 1.8ms preprocess, 12.4ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 17.4ms
# Speed: 5.5ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 17.6ms
# Speed: 5.9ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.4ms
# Speed: 4.7ms preprocess, 18.4ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 13.0ms
# Speed: 1.7ms preprocess, 13.0ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 17.6ms
# Speed: 5.7ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 19.6ms
# Speed: 1.6ms preprocess, 19.6ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 17.7ms
# Speed: 6.5ms preprocess, 17.7ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 13.4ms
# Speed: 1.9ms preprocess, 13.4ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.2ms
# Speed: 6.1ms preprocess, 18.2ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 17.6ms
# Speed: 5.1ms preprocess, 17.6ms inference, 3.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 23.5ms
# Speed: 7.1ms preprocess, 23.5ms inference, 4.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 23.8ms
# Speed: 3.1ms preprocess, 23.8ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 24.1ms
# Speed: 4.4ms preprocess, 24.1ms inference, 3.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 34.4ms
# Speed: 6.3ms preprocess, 34.4ms inference, 3.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 19.4ms
# Speed: 2.7ms preprocess, 19.4ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.5ms
# Speed: 6.4ms preprocess, 19.5ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.1ms
# Speed: 4.8ms preprocess, 19.1ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.2ms
# Speed: 5.5ms preprocess, 19.2ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.0ms
# Speed: 5.7ms preprocess, 19.0ms inference, 3.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.0ms
# Speed: 6.3ms preprocess, 19.0ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.8ms
# Speed: 4.4ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 9.8ms
# Speed: 1.9ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.8ms
# Speed: 4.7ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 1 , 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.8ms
# Speed: 4.4ms preprocess, 18.8ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 4.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.8ms
# Speed: 4.7ms preprocess, 18.8ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.8ms
# Speed: 6.2ms preprocess, 18.8ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.8ms
# Speed: 4.4ms preprocess, 18.8ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 10.3ms
# Speed: 1.6ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.4ms
# Speed: 5.1ms preprocess, 19.4ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 15.2ms
# Speed: 1.6ms preprocess, 15.2ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.7ms
# Speed: 5.5ms preprocess, 19.7ms inference, 4.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.7ms
# Speed: 6.3ms preprocess, 19.7ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 15.2ms
# Speed: 2.4ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.7ms
# Speed: 7.1ms preprocess, 19.7ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 14.9ms
# Speed: 1.6ms preprocess, 14.9ms inference, 3.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.4ms
# Speed: 4.5ms preprocess, 19.4ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 9.9ms
# Speed: 1.6ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.0ms
# Speed: 4.5ms preprocess, 19.0ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.1ms
# Speed: 4.1ms preprocess, 19.1ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.2ms
# Speed: 4.8ms preprocess, 19.2ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 15.5ms
# Speed: 1.4ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.2ms
# Speed: 4.6ms preprocess, 19.2ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 18.8ms
# Speed: 4.5ms preprocess, 18.8ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.3ms
# Speed: 5.3ms preprocess, 19.3ms inference, 3.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.1ms
# Speed: 5.1ms preprocess, 19.1ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.4ms
# Speed: 4.8ms preprocess, 19.4ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 22.4ms
# Speed: 7.6ms preprocess, 22.4ms inference, 3.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 20.7ms
# Speed: 2.7ms preprocess, 20.7ms inference, 4.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.0ms
# Speed: 8.2ms preprocess, 19.0ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 15.3ms
# Speed: 1.7ms preprocess, 15.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 19.0ms
# Speed: 7.3ms preprocess, 19.0ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 19.5ms
# Speed: 4.7ms preprocess, 19.5ms inference, 3.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 20.3ms
# Speed: 2.7ms preprocess, 20.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 21.5ms
# Speed: 6.5ms preprocess, 21.5ms inference, 4.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 13.9ms
# Speed: 1.9ms preprocess, 13.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 19.3ms
# Speed: 5.3ms preprocess, 19.3ms inference, 4.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 27.1ms
# Speed: 3.2ms preprocess, 27.1ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 27.0ms
# Speed: 11.7ms preprocess, 27.0ms inference, 3.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 23.7ms
# Speed: 3.1ms preprocess, 23.7ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 19.2ms
# Speed: 7.6ms preprocess, 19.2ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 34.0ms
# Speed: 6.1ms preprocess, 34.0ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 34.1ms
# Speed: 5.2ms preprocess, 34.1ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.2ms
# Speed: 2.1ms preprocess, 11.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 32.3ms
# Speed: 5.4ms preprocess, 32.3ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 32.2ms
# Speed: 5.1ms preprocess, 32.2ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 9.5ms
# Speed: 4.1ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.2ms
# Speed: 6.7ms preprocess, 31.2ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.3ms
# Speed: 3.8ms preprocess, 11.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.4ms
# Speed: 6.7ms preprocess, 31.4ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.2ms
# Speed: 7.6ms preprocess, 31.2ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.7ms
# Speed: 5.4ms preprocess, 31.7ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.5ms
# Speed: 6.0ms preprocess, 31.5ms inference, 3.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.3ms
# Speed: 4.4ms preprocess, 29.3ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.4ms
# Speed: 7.2ms preprocess, 29.4ms inference, 3.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.0ms
# Speed: 9.0ms preprocess, 29.0ms inference, 4.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 13.3ms
# Speed: 1.9ms preprocess, 13.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 28.8ms
# Speed: 5.1ms preprocess, 28.8ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.7ms
# Speed: 1.7ms preprocess, 11.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 28.9ms
# Speed: 4.8ms preprocess, 28.9ms inference, 4.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 28.9ms
# Speed: 6.6ms preprocess, 28.9ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 28.9ms
# Speed: 4.8ms preprocess, 28.9ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.4ms
# Speed: 4.0ms preprocess, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.5ms
# Speed: 4.7ms preprocess, 12.5ms inference, 1.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.9ms
# Speed: 4.0ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 10.2ms
# Speed: 3.5ms preprocess, 10.2ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 13.4ms
# Speed: 3.5ms preprocess, 13.4ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 12.2ms
# Speed: 1.6ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 13.3ms
# Speed: 3.7ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 18.0ms
# Speed: 5.4ms preprocess, 18.0ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 14.0ms
# Speed: 1.4ms preprocess, 14.0ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.0ms
# Speed: 7.5ms preprocess, 29.0ms inference, 4.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 26.2ms
# Speed: 2.9ms preprocess, 26.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 24.1ms
# Speed: 8.6ms preprocess, 24.1ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 19.8ms
# Speed: 2.0ms preprocess, 19.8ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 16.3ms
# Speed: 6.6ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 13.1ms
# Speed: 1.7ms preprocess, 13.1ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.6ms
# Speed: 4.7ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 14.4ms
# Speed: 4.1ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 15.6ms
# Speed: 4.4ms preprocess, 15.6ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 11.2ms
# Speed: 1.7ms preprocess, 11.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.1ms
# Speed: 5.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 12.2ms
# Speed: 1.3ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 10.9ms
# Speed: 3.7ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 13.4ms
# Speed: 1.4ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 11.9ms
# Speed: 4.3ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 9.4ms
# Speed: 4.8ms preprocess, 9.4ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 13.3ms
# Speed: 3.8ms preprocess, 13.3ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 11.5ms
# Speed: 4.3ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 9.9ms
# Speed: 1.4ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 13.5ms
# Speed: 5.1ms preprocess, 13.5ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 15.9ms
# Speed: 2.2ms preprocess, 15.9ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 14.7ms
# Speed: 5.8ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 9.9ms
# Speed: 1.2ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 17.9ms
# Speed: 4.3ms preprocess, 17.9ms inference, 3.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 19.9ms
# Speed: 5.0ms preprocess, 19.9ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 22.7ms
# Speed: 1.9ms preprocess, 22.7ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 16.2ms
# Speed: 4.2ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 288x640 1 , 1 , 1 , 4 s, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 800x480 1 License Plate, 16.0ms
# Speed: 4.4ms preprocess, 16.0ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 1 , 1 , 1 , 4 s, 12.2ms
# Speed: 2.1ms preprocess, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.6ms
# Speed: 4.0ms preprocess, 12.6ms inference, 3.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 1 , 1 , 20.6ms
# Speed: 1.5ms preprocess, 20.6ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 12.4ms
# Speed: 4.0ms preprocess, 12.4ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 1 , 1 , 15.9ms
# Speed: 1.7ms preprocess, 15.9ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 13.7ms
# Speed: 4.4ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 2 s, 1 , 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 16.2ms
# Speed: 4.1ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 1 , 1 , 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 13.8ms
# Speed: 4.7ms preprocess, 13.8ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 2 s, 1 , 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 14.9ms
# Speed: 4.5ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 1 , 1 , 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 12.9ms
# Speed: 4.8ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 2 s, 1 , 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 16.4ms
# Speed: 5.0ms preprocess, 16.4ms inference, 3.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 384x640 1 , 1 , 1 , 2 s, 1 , 19.0ms
# Speed: 2.5ms preprocess, 19.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x480 1 License Plate, 18.3ms
# Speed: 5.0ms preprocess, 18.3ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 384x640 1 , 1 , 1 , 1 , 1 , 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x480 1 License Plate, 26.5ms
# Speed: 4.3ms preprocess, 26.5ms inference, 3.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 384x640 1 , 1 , 1 , 1 , 1 , 13.3ms
# Speed: 1.5ms preprocess, 13.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x480 1 License Plate, 16.9ms
# Speed: 5.9ms preprocess, 16.9ms inference, 3.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 1 , 1 , 19.9ms
# Speed: 1.5ms preprocess, 19.9ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 15.1ms
# Speed: 4.9ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 384x640 1 , 1 , 1 , 1 , 1 , 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x480 1 License Plate, 32.0ms
# Speed: 6.4ms preprocess, 32.0ms inference, 7.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 384x640 1 , 1 , 1 , 1 , 1 , 32.5ms
# Speed: 4.6ms preprocess, 32.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x480 1 License Plate, 19.5ms
# Speed: 6.0ms preprocess, 19.5ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 1 , 1 , 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 18.8ms
# Speed: 4.8ms preprocess, 18.8ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 384x640 1 , 1 , 1 , 1 , 1 , 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x480 1 License Plate, 20.6ms
# Speed: 4.3ms preprocess, 20.6ms inference, 3.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 1 , 1 , 1 , 1 , 1 , 16.4ms
# Speed: 1.6ms preprocess, 16.4ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 14.6ms
# Speed: 5.2ms preprocess, 14.6ms inference, 3.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 384x640 1 , 1 , 1 , 1 , 1 , 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 800x480 1 License Plate, 14.7ms
# ...
#
# 0: 320x640 3 s, 4 s, 20.7ms
# Speed: 2.5ms preprocess, 20.7ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 19.3ms
# Speed: 5.2ms preprocess, 19.3ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 13.8ms
# Speed: 1.6ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 18.0ms
# Speed: 6.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.6ms
# Speed: 6.3ms preprocess, 17.6ms inference, 3.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 21.4ms
# Speed: 2.0ms preprocess, 21.4ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 18.0ms
# Speed: 5.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 17.7ms
# Speed: 2.1ms preprocess, 17.7ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.8ms
# Speed: 6.3ms preprocess, 17.8ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 25.4ms
# Speed: 2.1ms preprocess, 25.4ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.6ms
# Speed: 5.0ms preprocess, 17.6ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 14.5ms
# Speed: 2.9ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.7ms
# Speed: 5.6ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.9ms
# Speed: 5.0ms preprocess, 17.9ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.6ms
# Speed: 5.6ms preprocess, 17.6ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 20.3ms
# Speed: 2.3ms preprocess, 20.3ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 18.6ms
# Speed: 5.3ms preprocess, 18.6ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 20.5ms
# Speed: 6.4ms preprocess, 20.5ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 15.2ms
# Speed: 1.6ms preprocess, 15.2ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 28.9ms
# Speed: 10.6ms preprocess, 28.9ms inference, 5.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 28.4ms
# Speed: 3.8ms preprocess, 28.4ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.7ms
# Speed: 6.1ms preprocess, 17.7ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 18.0ms
# Speed: 1.7ms preprocess, 18.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.6ms
# Speed: 4.8ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 33.4ms
# Speed: 5.5ms preprocess, 33.4ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 14.8ms
# Speed: 3.6ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 33.3ms
# Speed: 5.2ms preprocess, 33.3ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 32.7ms
# Speed: 8.0ms preprocess, 32.7ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 20.5ms
# Speed: 2.6ms preprocess, 20.5ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 32.3ms
# Speed: 6.3ms preprocess, 32.3ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 17.5ms
# Speed: 2.7ms preprocess, 17.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 32.4ms
# Speed: 9.4ms preprocess, 32.4ms inference, 4.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 16.9ms
# Speed: 3.7ms preprocess, 16.9ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 32.1ms
# Speed: 5.4ms preprocess, 32.1ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 21.1ms
# Speed: 1.9ms preprocess, 21.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 32.0ms
# Speed: 10.7ms preprocess, 32.0ms inference, 4.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 33.9ms
# Speed: 3.8ms preprocess, 33.9ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.9ms
# Speed: 8.5ms preprocess, 31.9ms inference, 4.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.8ms
# Speed: 7.2ms preprocess, 31.8ms inference, 4.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 15.3ms
# Speed: 3.3ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.9ms
# Speed: 7.2ms preprocess, 31.9ms inference, 3.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 15.3ms
# Speed: 1.7ms preprocess, 15.3ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.4ms
# Speed: 6.2ms preprocess, 31.4ms inference, 4.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 31.2ms
# Speed: 5.6ms preprocess, 31.2ms inference, 3.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 15.8ms
# Speed: 3.0ms preprocess, 15.8ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 30.7ms
# Speed: 7.9ms preprocess, 30.7ms inference, 2.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 13.2ms
# Speed: 1.9ms preprocess, 13.2ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 30.3ms
# Speed: 8.4ms preprocess, 30.3ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 30.1ms
# Speed: 6.7ms preprocess, 30.1ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 35.8ms
# Speed: 11.6ms preprocess, 35.8ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 22.6ms
# Speed: 3.6ms preprocess, 22.6ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.4ms
# Speed: 5.2ms preprocess, 29.4ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 18.5ms
# Speed: 4.7ms preprocess, 18.5ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.2ms
# Speed: 7.8ms preprocess, 29.2ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 21.2ms
# Speed: 2.3ms preprocess, 21.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.5ms
# Speed: 7.4ms preprocess, 29.5ms inference, 2.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.0ms
# Speed: 6.5ms preprocess, 29.0ms inference, 3.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 29.5ms
# Speed: 6.7ms preprocess, 29.5ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 32.1ms
# Speed: 10.2ms preprocess, 32.1ms inference, 4.4ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 10.5ms
# Speed: 4.4ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 9.8ms
# Speed: 1.4ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 17.6ms
# Speed: 5.1ms preprocess, 17.6ms inference, 3.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 14.0ms
# Speed: 5.4ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 18.8ms
# Speed: 1.4ms preprocess, 18.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 11.1ms
# Speed: 5.2ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 16.0ms
# Speed: 5.6ms preprocess, 16.0ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 20.4ms
# Speed: 1.7ms preprocess, 20.4ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 13.7ms
# Speed: 7.1ms preprocess, 13.7ms inference, 2.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 16.7ms
# Speed: 5.9ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 16.6ms
# Speed: 4.3ms preprocess, 16.6ms inference, 2.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 16.1ms
# Speed: 1.4ms preprocess, 16.1ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 13.1ms
# Speed: 6.9ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 17.2ms
# Speed: 2.8ms preprocess, 17.2ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 26.8ms
# Speed: 7.4ms preprocess, 26.8ms inference, 4.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 12.9ms
# Speed: 7.3ms preprocess, 12.9ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 13.6ms
# Speed: 1.6ms preprocess, 13.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 19.6ms
# Speed: 9.4ms preprocess, 19.6ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 42.6ms
# Speed: 2.5ms preprocess, 42.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 25.9ms
# Speed: 8.0ms preprocess, 25.9ms inference, 3.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 20.3ms
# Speed: 2.1ms preprocess, 20.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 21.4ms
# Speed: 8.5ms preprocess, 21.4ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 19.3ms
# Speed: 2.6ms preprocess, 19.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 21.8ms
# Speed: 6.1ms preprocess, 21.8ms inference, 4.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 3 s, 4 s, 22.3ms
# Speed: 2.2ms preprocess, 22.3ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 18.7ms
# Speed: 9.0ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 3 s, 4 s, 18.2ms
# Speed: 2.7ms preprocess, 18.2ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 22.9ms
# Speed: 8.9ms preprocess, 22.9ms inference, 4.1ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 3 s, 4 s, 21.0ms
# Speed: 2.7ms preprocess, 21.0ms inference, 4.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 22.9ms
# Speed: 6.8ms preprocess, 22.9ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 3 s, 5 s, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 22.0ms
# Speed: 5.9ms preprocess, 22.0ms inference, 3.8ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 3 s, 4 s, 20.0ms
# Speed: 1.7ms preprocess, 20.0ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 26.6ms
# Speed: 7.6ms preprocess, 26.6ms inference, 3.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 3 s, 4 s, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 11.1ms
# Speed: 5.5ms preprocess, 11.1ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 3 s, 4 s, 13.1ms
# Speed: 2.1ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 20.9ms
# Speed: 6.3ms preprocess, 20.9ms inference, 3.9ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 14.8ms
# Speed: 6.4ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 800x480 1 License Plate, 16.9ms
# Speed: 4.9ms preprocess, 16.9ms inference, 3.3ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 352x640 3 s, 4 s, 22.9ms
# Speed: 2.9ms preprocess, 22.9ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 800x480 1 License Plate, 21.9ms
# Speed: 7.4ms preprocess, 21.9ms inference, 2.6ms postprocess per image at shape (1, 3, 800, 480)
#
# 0: 320x640 3 s, 4 s, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
